# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('../CapStone/LetsModelBaby.csv')

# dropping unecessary columns
df.drop('Unnamed: 0', inplace=True, axis=1)

df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /Users/elutins/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Date          Pitcher1 Pitcher_Team1  Pitcher1_BB%  Pither1_CG  \
# 0 2016-05-19  Mike Foltynewicz           ATL      0.026316         0.0
# 1 2016-07-10  Mike Foltynewicz           ATL      0.061453         0.0
# 2 2016-07-21  Mike Foltynewicz           ATL      0.056522         0.0
# 3 2016-07-27  Mike Foltynewicz           ATL      0.070588         0.0
# 4 2016-08-12  Mike Foltynewicz           ATL      0.069277         0.0
#
#    Pitcher1_ERA  Pitcher1_HR/9  Pitcher1_K%  Pitcher1_ShO  Pitcher1_WHIP  \
# 0      2.967033       1.978022     0.210526             0       1.208791
# 1      4.433498       2.438424     0.195531             0       1.354680
# ...

# %%
df.head()
# Out:
#         Date          Pitcher1 Pitcher_Team1  Pitcher1_BB%  Pither1_CG  \
# 0 2016-05-19  Mike Foltynewicz           ATL      0.026316         0.0
# 1 2016-07-10  Mike Foltynewicz           ATL      0.061453         0.0
# 2 2016-07-21  Mike Foltynewicz           ATL      0.056522         0.0
# 3 2016-07-27  Mike Foltynewicz           ATL      0.070588         0.0
# 4 2016-08-12  Mike Foltynewicz           ATL      0.069277         0.0
#
#    Pitcher1_ERA  Pitcher1_HR/9  Pitcher1_K%  Pitcher1_ShO  Pitcher1_WHIP  \
# 0      2.967033       1.978022     0.210526             0       1.208791
# 1      4.433498       2.438424     0.195531             0       1.354680
# 2      3.791209       1.813187     0.217391             0       1.208791
# 3      3.913043       1.806020     0.215686             0       1.254181
# 4      4.500000       1.539474     0.198795             0       1.342105
#
#    BattingTeam1_RBIs/Game BattingTeam1  BattingTeam1_AVG  BattingTeam1_BABIP  \
# ...

# %%
# SETTING THE DATE AS THE INDEX FOR MORE EFFICIENT EDA
df.set_index('Date', drop=False, inplace=True)

# %%
# BATTING TEAM
df.groupby('BattingTeam1')['Total Runs in Game'].describe().sort_values('mean', ascending=False)
# THIS SHOWS THAT OVER THE COURSE OF THE ENTIRE DATAFRAME, WHICH ENCOMPASSES GAMES FROM MAY - OCTOBER IN 
# 2009 - 2016, THE MOST RUNS WERE SCORED IN COLORADO, BOSTON, TEXAS, ARIZONA, AND TORONTO'S BALLPARKS
# Out:
#               count       mean       std  min  25%   50%   75%   max
# BattingTeam1
# COL           450.0  11.502222  4.982933  1.0  8.0  11.0  15.0  26.0
# BOS           477.0  10.113208  5.140032  1.0  6.0   9.0  13.0  32.0
# TEX           475.0  10.033684  5.025140  1.0  7.0   9.0  13.0  29.0
# ARI           454.0   9.603524  4.516009  1.0  7.0   9.0  12.0  26.0
# TOR           472.0   9.591102  4.522199  1.0  6.0   9.0  12.0  28.0
# MIN           481.0   9.513514  4.415447  1.0  7.0   9.0  12.0  26.0
# BAL           486.0   9.310700  4.457378  1.0  6.0   9.0  12.0  28.0
# NYY           481.0   9.303534  4.404468  1.0  6.0   9.0  12.0  31.0
# DET           477.0   9.299790  4.187348  1.0  6.0   9.0  12.0  25.0
# FLA           173.0   9.179191  4.661473  1.0  6.0   9.0  12.0  26.0
# CHW           463.0   9.129590  4.500655  1.0  6.0   9.0  12.0  27.0
# KCR           456.0   9.122807  4.350350  1.0  6.0   9.0  12.0  22.0
# ...

# %%
# WRITING CODE TO ITERATE OVER EVERY HOME STADIUM IN THE LEAGUE, AND PRINT OUT THE PERCENTAGES OF ALL THE GAMES
# PLAYED IN THAT STADIUM, HOW MANY HIT THE OVER AND HOW MANY HIT THE UNDER

for i in (set(df['BattingTeam1'].values)):
    print i
    print df.loc[df['BattingTeam1'] == i]['Over hit?'].value_counts(normalize=True)
    print "---------------------------"
# Out:
# NYY
# 0    0.538462
# 1    0.461538
# Name: Over hit?, dtype: float64
# ---------------------------
# MIL
# 1    0.511848
# 0    0.488152
# Name: Over hit?, dtype: float64
# ---------------------------
# MIN
# 1    0.536383
# 0    0.463617
# Name: Over hit?, dtype: float64
# ---------------------------
# TOR
# 0    0.502119
# 1    0.497881
# Name: Over hit?, dtype: float64
# ---------------------------
# ATL
# 0    0.565789
# 1    0.434211
# Name: Over hit?, dtype: float64
# ---------------------------
# BOS
# 1    0.507338
# 0    0.492662
# Name: Over hit?, dtype: float64
# ---------------------------
# OAK
# 0    0.503212
# 1    0.496788
# Name: Over hit?, dtype: float64
# ---------------------------
# CIN
# 0    0.535109
# 1    0.464891
# Name: Over hit?, dtype: float64
# ---------------------------
# WSN
# 1    0.512821
# 0    0.487179
# Name: Over hit?, dtype: float64
# ---------------------------
# NYM
# 0    0.527578
# 1    0.472422
# Name: Over hit?, dtype: float64
# ...

# %%
# SIMILAR TO ABOVE, WRITING CODE TO ITERATE OVER EVERY HOME STADIUM IN THE LEAGUE, AND PRINT OUT THE PERCENTAGES OF ALL THE GAMES
# PLAYED IN THAT STADIUM, HOW MANY TIMES THE HOME TEAM WON
for i in (set(df['BattingTeam1'].values)):
    print i
    print df.loc[df['BattingTeam1'] == i]['Home_Team_Win?'].value_counts(normalize=True)
    print "---------------------------"
# Out:
# NYY
# 1    0.594595
# 0    0.405405
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# MIL
# 1    0.540284
# 0    0.459716
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# MIN
# 0    0.557173
# 1    0.442827
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# TOR
# 1    0.54661
# 0    0.45339
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# ATL
# 1    0.54386
# 0    0.45614
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# BOS
# 1    0.540881
# 0    0.459119
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# OAK
# 1    0.541756
# 0    0.458244
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# CIN
# 1    0.513317
# 0    0.486683
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# WSN
# 1    0.554779
# 0    0.445221
# Name: Home_Team_Win?, dtype: float64
# ---------------------------
# NYM
# 0    0.532374
# 1    0.467626
# ...
